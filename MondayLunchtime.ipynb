# %% [markdown]
# # Python in the New Era of Astronomy
#
# ## Szymon Prajs

# %% [markdown]
# # What is this talk about?

# %% [markdown]
# ## Python in Astronomy

# %%
from IPython.display import Image

# %%
Image("https://pbs.twimg.com/media/Cuy1q3qWIAAE1Fc.jpg")

# %% [markdown]
# ## Python Revolution

# %% [markdown]
# ## But why?
#
# What makes Python stands out and how is it taking over the world

# %% [markdown]
# ### Readability
# There is a reason why all universities teach Python, it's simple

# %% [markdown]
# ###  Extentions
